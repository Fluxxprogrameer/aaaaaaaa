# %% [markdown]
# <a href="https://colab.research.google.com/github/Fluxxprogrameer/aaaaaaaa/blob/main/tallerEnClaseyoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Taller 1 **Introducción a la Programación**
# * Nombre: Ingrese su nombre completo
# * Código: Ingrese su código
#
#
# * el taller solo aplicará el beneficio de 3 decimas en el Quiz, si tienen una nota igual o superior a 3.0 en el parcial.
# * el uso de gemini o cualquier AI en el taller anulará su nota, siendo 0. (yo me doy cuenta si usan metodos, funciones o objetos no vistos en clase)
# * hacer las preguntas necesarias durante el desarrollo del taller, el día del examen no se responden dudas.
# * al entregar el taller se aceptna estas reglas, en caso de no entregarlo su nota sera de 0.

# %% [markdown]
# #Cómo desactivo Gemini?
# se debe ir a Settings y desmarcar las opciones que se ven en la foto
# ![Captura de pantalla 2024-08-22 a la(s) 9.50.36 p. m..png](data:image/png;base64,...)

# %% [markdown]
# #1. Creación de Variables y Tipos de Datos

# %% [markdown]
# Crea una variable para almacenar tu nombre y muestra su tipo de dato.

# %%
nombre="Martin"
print(nombre, type(nombre))
# Out:
# martin <class 'str'>

# %% [markdown]
# Crea una variable para almacenar tu edad y muestra su tipo de dato.

# %%
edad=17
print(edad, type(edad))
# Out:
# 17 <class 'int'>

# %% [markdown]
# Crea una variable para almacenar tu altura en metros y muestra su tipo de dato.

# %%
altura= 1.80
print(altura , "metros")
print (type(altura))
# Out:
# 1.8 metros
# <class 'float'>

# %% [markdown]
# #2. Entrada de Datos con input

# %% [markdown]
# Pide al usuario que ingrese su nombre y muestra el tipo de dato de la entrada.

# %%
nombre=input("ingresa tu nombre")
print("Tu nombre es",nombre )
print(type(nombre))
# Out:
# ingresa tu nombreMartin
# Tu nombre es Martin
# <class 'str'>

# %% [markdown]
# Pide al usuario que ingrese su edad y muestra el tipo de dato de la entrada.

# %%
edad=int(input("ingresa tu edad"))
print("Tu edad es" , edad , "años")
print(type(edad))
# Out:
# ingresa tu edad78
# Tu edad es 78 años
# <class 'int'>

# %% [markdown]
# #3. Conversión de Tipos de Datos

# %% [markdown]
# Convierte la entrada de edad del usuario a un entero y muestra su tipo de dato.

# %%
edad=input("ingresa tu edad")
print("Tu edad es" , edad , "años")
print(type(edad))
edad=int
print(edad)
# Out:
# ingresa tu edad43
# Tu edad es 43 años
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Convierte una entrada de altura a un número flotante y muestra su tipo de dato.

# %%
estatura=input("Ingresa tu estatura")
print(estatura)
print(type(estatura))
estatura=float
print(estatura)
# Out:
# Ingresa tu estatura1.80
# 1.80
# <class 'str'>
# <class 'float'>

# %% [markdown]
# # 4. Operaciones Matemáticas

# %% [markdown]
# Realiza una suma de dos números y muestra el resultado.

# %%
a=23
b=32
print(a+b)
# Out:
# 6

# %% [markdown]
# Realiza una resta de dos números y muestra el resultado.

# %%
a=12
b=394
print(b-a)
# Out:
# 382

# %% [markdown]
# Realiza una multiplicación de dos números y muestra el resultado.

# %%
a=42
b=452
print(a*b)
# Out:
# 18984

# %% [markdown]
# Realiza una división de dos números y muestra el resultado.

# %%
a=2332
b=2342
print(a/b)
# Out:
# 0.9957301451750641

# %% [markdown]
# Realiza una división entera de dos números y muestra el resultado.

# %%
a=43
b=23
print(a//b)
# Out:
# 1

# %% [markdown]
# Encuentra el residuo de una división entre dos números y muestra el resultado.

# %%
a=25
b=3
print(a%b)
# Out:
# 1

# %% [markdown]
# #5. Operaciones Lógicas

# %% [markdown]
# Demuestra el uso de and con dos condiciones.

# %%
if o==9 and i==23:
  print(o=i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-9d443260d91f> in <cell line: 1>()
# ----> 1 if o==9 and i==23:
#       2   print(o==i)
#
# NameError: name 'o' is not defined

# %% [markdown]
# Demuestra el uso de or con dos condiciones.

# %%
if o==9 or i==23:
  print(o=i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-c1b06488f9ae> in <cell line: 1>()
# ----> 1 if o==9 or i==23:
#       2   print(o=i)
#
# NameError: name 'o' is not defined

# %% [markdown]
# Compara dos números para ver cuál es mayor.

# %%
a=32
b=71
print(a>b)
# Out:
# False

# %% [markdown]
# Compara dos números para ver cuál es menor.

# %%
n=23
e=134233
print(n<e)
# Out:
# True

# %% [markdown]
# #6. Uso de Condicionales if, elif, else

# %% [markdown]
# Escribe un programa que pida al usuario su edad y determine si es mayor de edad.

# %%
edad=int(input("ingrese su edad"))
if edad>=18:
  print("es mayor de edad")
else:
    print("no es mayor de edad")
# Out:
# ingrese su edad18
# es mayor de edad

# %% [markdown]
# Escribe un programa que pida dos números al usuario y determine cuál es el mayor.

# %%
N1=input("primer numero")
N2=input("segundo numero")
if N1>N2:
  print("N1 es mayor")
elif N1==N2:
  print("Ambos numeros son iguales")
else:
    print("N2 es mayor")
# Out:
# primer numero12
# segundo numero34
# N2 es mayor

# %% [markdown]
# Escribe un programa que pida tres números y determine cuál es el mayor y cuál es el menor.

# %% [markdown]
# Calcular la calificación final basada en la nota del estudiante.
#
# El programa debe pedir al usuario su nota final (entre 0 y 100) y determinar la calificación en letras siguiendo esta escala:
#
# * A: 90 - 100
# * B: 80 - 89
# * C: 70 - 79
# * D: 60 - 69
# * F: Menos de 60

# %% [markdown]
# Verificar si una fecha ingresada por el usuario es válida.
#
# El programa debe pedir al usuario el día, el mes y el año y verificar si la fecha es válida. Asume que el año es bisiesto si es divisible por 4, pero no es divisible por 100 a menos que también sea divisible por 400.

# %% [markdown]
# Determinar el tipo de triángulo basado en los lados ingresados.
#
# El programa debe pedir al usuario los tres lados de un triángulo y determinar si es un triángulo equilátero, isósceles o escaleno.

# %% [markdown]
# Determinar el trimestre del año basado en el mes ingresado.
#
# El programa debe pedir al usuario el mes y determinar en qué trimestre del año cae:
#
# * Trimestre 1: Enero, Febrero, Marzo
# * Trimestre 2: Abril, Mayo, Junio
# * Trimestre 3: Julio, Agosto, Septiembre
# * Trimestre 4: Octubre, Noviembre, Diciembre

# %% [markdown]
# Determinar si un número ingresado es positivo, negativo o cero, y también si es par o impar.

# %% [markdown]
# Clasificar un número según su rango.
#
# El programa debe pedir un número y clasificarlo en uno de los siguientes rangos:
#
# * "Menor a 0"
# * "0 a 10"
# * "11 a 50"
# * "Mayor a 50"

# %% [markdown]
# Determinar la categoría de edad basada en la entrada del usuario.
#
# El programa debe pedir al usuario su edad y clasificarlo en:
#
# * "Infante" (0-5 años)
# * "Niño" (6-12 años)
# * "Adolescente" (13-17 años)
# * "Adulto" (18-64 años)
# * "Anciano" (65 años o más)

# %% [markdown]
# Determinar si un año es bisiesto sin usar el operador %.
#
# El año debe ser divisible por 4 y no divisible por 100, a menos que también sea divisible por 400. Realiza la operación sin usar %.

# %% [markdown]
# Calcular el costo de una llamada telefónica.
#
# El programa debe pedir al usuario el tiempo en minutos que ha durado la llamada y el tipo de llamada. Los tipos de llamada y sus tarifas son:
#
# * Local: $0.10 por minuto
# * Nacional: $0.25 por minuto
# * Internacional: $0.50 por minuto
# * Luego, el programa debe calcular y mostrar el costo total de la llamada.

# %% [markdown]
# Clasificar una secuencia de tres números en orden creciente, decreciente o no ordenada.
#
# El programa debe pedir tres números al usuario y clasificar la secuencia en:
#
# * Creciente: si el primer número es menor que el segundo y el segundo menor que el tercero
# * Decreciente: si el primer número es mayor que el segundo y el segundo mayor que el tercero
# * No ordenada: cualquier otro caso

# %% [markdown]
# Determinar si un año es un año fiscal bisiesto, basado en una regla específica.
#
# Un año fiscal bisiesto debe ser divisible por 4, pero no por 100, a menos que también sea divisible por 200.

# %% [markdown]
# Determinar el tipo de cuadrilátero basado en los ángulos internos.
#
# El programa debe pedir al usuario los cuatro ángulos internos de un cuadrilátero y verificar si forman un cuadrilátero válido. Luego, debe clasificarlo como:
#
# * Cuadrado: todos los ángulos son 90 grados
# * Rectángulo: todos los ángulos suman 360 grados, pero no todos son 90 grados
# * Trapecio: dos ángulos son iguales y los otros dos son iguales
# * Otro: cualquier otro tipo de cuadrilátero

# %% [markdown]
# Calculadora de IMC (Índice de Masa Corporal) con categorías.
#
# El programa debe pedir al usuario su peso en kilogramos y su altura en metros. Luego, debe calcular el IMC y determinar la categoría en la que se encuentra:
#
# * Bajo peso: IMC < 18.5
# * Normal: 18.5 ≤ IMC < 24.9
# * Sobrepeso: 25 ≤ IMC < 29.9
# * Obesidad: IMC ≥ 30
